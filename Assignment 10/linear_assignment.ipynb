# %%
import pandas as pd

# %%
df = pd.read_csv("canada_pincome.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.rename(columns={"income": "pc_income"}, inplace=True)
df.head()
# Out:
#    year    pc_income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
print(df.dtypes)
# Out:
# year           int64
# pc_income    float64
# dtype: object

# %%
X = df[['year']]
X.head()
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
Y = df[['pc_income']]
Y.head()
# Out:
#      pc_income
# 0  3399.299037
# 1  3768.297935
# 2  4251.175484
# 3  4804.463248
# 4  5576.514583

# %%
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
# model.fit(X,Y)

split_index = int(len(df) * 0.9)
X_train = X[:split_index]
X_test = X[split_index:]

Y_train = Y[:split_index]
Y_test = Y[split_index:]
# Out:
# 42

# %%
# Y_pred = model.predict(X)
